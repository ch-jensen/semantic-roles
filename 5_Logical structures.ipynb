# %% [markdown]
# # Logical structures
#
# The content of this notebook is to compute logical strucures of Biblical Hebrew verbs according to the Role and Reference Grammar definitions.
#
# A basic requirement is to distinguish between stative and active verbs as well as causative and non-causative verbs. This issue has been dealt with in another notebook. Another requirement is to distinguish between intransitive and transitive verbs, a task that is not easy for Biblical Hebrew because the object of a verb is not obligatory. It may be realized as an independent lexeme or as a suffix, but it may also only be inferred from the context.
#
# The strategy applied here is to search the full corpus (Genesis-Kings) for all instances of each verb in the *qal* stem. If the verb never occurs with an object, it is regarded as intransitive, but if it occurs one or several times with an object, it is considered transitive

# %%
import collections
import pandas as pd
import numpy as np
from tf.app import use

# %%
A = use('bhsa', hoist=globals())
# Out:
# TF app is up-to-date.
# Using annotation/app-bhsa commit 35e4fee27a1cd6f0a5caea9118129349ddb0604e (=latest)
#   in C:\Users\Ejer/text-fabric-data/__apps__/bhsa.
# Using etcbc/bhsa/tf - c r1.4 in C:\Users\Ejer/text-fabric-data
# Using etcbc/phono/tf - c r1.1 in C:\Users\Ejer/text-fabric-data
# Using etcbc/parallels/tf - c r1.1 in C:\Users\Ejer/text-fabric-data
# <b>Documentation:</b> <a target="_blank" href="https://etcbc.github.io/bhsa" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Hebrew" title="('Hebrew characters and transcriptions',)">Character table</a> <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="BHSA feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-bhsa" title="bhsa API documentation">bhsa API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.5.4</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b>: <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\book.tf">book</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\book@am.tf">book@ll</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\chapter.tf">chapter</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\code.tf">code</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\det.tf">det</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\freq_lex.tf">freq_lex</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\function.tf">function</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\g_word.tf">g_word</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\g_word_utf8.tf">g_word_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\gloss.tf">gloss</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\gn.tf">gn</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/label" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\label.tf">label</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/language" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\language.tf">language</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/lex" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\lex.tf">lex</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/lex_utf8" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\lex_utf8.tf">lex_utf8</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/ls" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\ls.tf">ls</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/nametype" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\nametype.tf">nametype</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/nme" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\nme.tf">nme</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/nu" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\nu.tf">nu</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/number" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\number.tf">number</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/otype" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\otype.tf">otype</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/pdp" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\pdp.tf">pdp</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/pfm" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\pfm.tf">pfm</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/prs" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\prs.tf">prs</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/prs_gn" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\prs_gn.tf">prs_gn</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/prs_nu" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\prs_nu.tf">prs_nu</a>  <a target="_blank" href="https://etcbc.github.io/bhsa/features/prs_ps" title="C:\Users\Ejer/text-fabric-data/etcbc/bhsa/tf/c\prs_ps.tf">prs_ps</a>  ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.lno,.catom.lno,.patom.lno {
#     border-left-style: none
# }
# .satom.rno,.catom.rno,.patom.rno {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# ## Preparing the corpus

# %%
# prepare the corpus

corpus = [book for book in F.otype.s('book') if book < T.nodeFromSection(('Isaiah',))]
print('Corpus:\n')
print('\n'.join(T.sectionFromNode(book)[0] for book in corpus))
# Out:
# Corpus:
#
# Genesis
# Exodus
# Leviticus
# Numbers
# Deuteronomy
# Joshua
# Judges
# 1_Samuel
# 2_Samuel
# 1_Kings
# 2_Kings

# %%
sets={'corpus':corpus} # make set for searching

# %% [markdown]
# ## Data extraction
#
# The verbs are extracted according to the transitivity frames in which they occur. Here, only intransitive and transitive frames are of importance, hence, ditransitive frames are not specified and will be included in single transitive frames.

# %%
#Intransitive frame without object. Subject may be implicit or explicit.
intransitive = '''
corpus
 clause
 /without/
    phrase function=Objc
 /-/
   phrase function=Pred|PreS
     word lex#HJH[ sp=verb vs=qal language=Hebrew
'''

#Transitive frame with object suffix.
transitive1 = '''
corpus
 clause
   phrase function=PreO
     word lex#HJH[ sp=verb vs=qal language=Hebrew
'''

#Transitive frame with lexical object
transitive2 = '''
corpus
 clause
   phrase function=Pred|PreS
     word lex#HJH[ sp=verb vs=qal language=Hebrew
   phrase function=Objc
'''

# %%
frames = {'(S)':intransitive, '(S)-O_sfx':transitive1, '(S)-O':transitive2}

verb_constructions = {}

n=0
for fr in frames:
    
    clause = ''
    lex = ''
    stem = ''
    
    results = A.search(frames[fr], sets=sets, silent=True)
    
    for r in results:
        
        clause = r[1]
        lex = F.lex.v(r[3])
        cmpl_prep = ''

        verb_constructions[clause] = [lex, fr]
            
    n+=1
    print(f'... frame {n} completed')
# Out:
# ... frame 1 completed
# ... frame 2 completed
# ... frame 3 completed

# %%
df = pd.DataFrame(verb_constructions).T
df.columns = ['lex','frame']

# %%
df.head
# Out:
# <bound method NDFrame.head of          lex  frame
# 427557  >MR[    (S)
# 427561  VWB[    (S)
# 427568  >MR[    (S)
# 427580  >MR[    (S)
# 427586  R>H[    (S)
# 427587  VWB[    (S)
# 427588  >MR[    (S)
# 427598  R>H[    (S)
# 427599  VWB[    (S)
# 427603  >MR[    (S)
# 427613  MCL[    (S)
# 427615  R>H[    (S)
# 427616  VWB[    (S)
# 427620  >MR[    (S)
# 427626  CRY[    (S)
# 427628  R>H[    (S)
# 427629  VWB[    (S)
# 427631  >MR[    (S)
# 427632  PRH[    (S)
# 427633  RBH[    (S)
# 427635  RBH[    (S)
# 427639  >MR[    (S)
# 427646  R>H[    (S)
# 427647  VWB[    (S)
# 427648  >MR[    (S)
# 427650  RDH[    (S)
# 427656  >MR[    (S)
# 427657  PRH[    (S)
# 427658  RBH[    (S)
# 427661  RDH[    (S)
# ...      ...    ...
# 467944  R>H[  (S)-O
# 467948  LQX[  (S)-O
# 467949  MCX[  (S)-O
# 467955  <FH[  (S)-O
# 467959  NTN[  (S)-O
# 467962  LQX[  (S)-O
# 467965  NTN[  (S)-O
# 467967  NTN[  (S)-O
# 467969  NGF[  (S)-O
# 467975  <FH[  (S)-O
# 468000  LQX[  (S)-O
# 468006  <FH[  (S)-O
# 468013  LQX[  (S)-O
# 468033  <FH[  (S)-O
# 468042  BNH[  (S)-O
# 468055  TPF[  (S)-O
# 468058  CXV[  (S)-O
# 468064  FRP[  (S)-O
# 468065  FRP[  (S)-O
# 468066  NTY[  (S)-O
# 468075  NF>[  (S)-O
# 468076  LQX[  (S)-O
# 468078  LQX[  (S)-O
# 468090  LQX[  (S)-O
# 468091  LQX[  (S)-O
# 468096  LQX[  (S)-O
# 468113  <BD[  (S)-O
# 468126  NF>[  (S)-O
# 468129  NTN[  (S)-O
# 468132  >KL[  (S)-O
#
# [20696 rows x 2 columns]>

# %% [markdown]
# Are all relevant verbs extracted? We can find out by comparing with a singular search that extracts all verbs regardless of frame:

# %%
verbs = '''
corpus
 clause
  phrase function=Pred|PreO|PreS
   word lex#HJH[ sp=verb vs=qal language=Hebrew
'''

results_all_verbs = A.search(verbs, sets=sets)
# Out:
#   3.00s 20697 results

# %%
print(f'Number of cases in transitivity dataset: {len(df)}')
print(f'Number of all verbs regardless of transitivity frames: {len(results_all_verbs)}')
print(f'\nDifference: {len(results_all_verbs)-len(df)}')
# Out:
# Number of cases in transitivity dataset: 20696
# Number of all verbs regardless of transitivity frames: 20697
#
# Difference: 1

# %% [markdown]
# Which clauses are different?

# %%
mismatches = []
df_clauses = list(df.index)

for r in results_all_verbs:
    clause = r[1]
    if clause not in df_clauses:
        mismatches.append(clause)
        
len(mismatches)
# Out:
# 0

# %% [markdown]
# A clause may occur twice in the results of all verbs regardless of transitivity frames. We can check that:

# %%
clauses = []

for r in results_all_verbs:
    clause = r[1]
    clauses.append(clause)
    
collections.Counter(clauses).most_common()[:10]
# Out:
# [(431017, 2),
#  (427553, 1),
#  (427557, 1),
#  (427560, 1),
#  (427561, 1),
#  (427563, 1),
#  (427564, 1),
#  (427568, 1),
#  (427571, 1),
#  (427576, 1)]

# %% [markdown]
# In fact, a clause occurs twice because it has two phrases with object suffix. In the first data extraction the same clause only occurs once because it is added to a dictionary, and in effect, the second instance overwriting the first. Anyway, the clause needs only be represented once, so we can ignore this inconsistency.

# %%
A.pretty(431017)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 31:39">Genesis 31:39</a>
# <div class="atoms  " >
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">clause</a>   <span class="typ">xYq0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="show this lexeme in SHEBANQ">מִ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">prep</a></span> <span class="gloss">from</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MN</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JDn" title="show this lexeme in SHEBANQ">יָּדִ֖י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">subs</a></span> <span class="gloss">hand</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JD/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">phrase</a>   <span class="function">PreO</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BQCv" title="show this lexeme in SHEBANQ">תְּבַקְשֶׁ֑נָּה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">verb</a></span> <span class="gloss">seek</span> <span class="vs">piel</span> <span class="vt">impf</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>BQC[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">phrase</a>   <span class="function">PreO</span> <span class="typ">VP|NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1GNBv" title="show this lexeme in SHEBANQ">גְּנֻֽבְתִ֣י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">subs</a></span> <span class="gloss">steal</span> <span class="vs">qal</span> <span class="vt">ptcp</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>GNB[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹ֔ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">subs</a></span> <span class="gloss">day</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JWM/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1GNBv" title="show this lexeme in SHEBANQ">גְנֻֽבְתִ֖י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">subs</a></span> <span class="gloss">steal</span> <span class="vs">qal</span> <span class="vt">ptcp</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>GNB[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LJLHn" title="show this lexeme in SHEBANQ">לָֽיְלָה׃ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=31&amp;verse=39&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 31:39" sec="Genesis 31:39">subs</a></span> <span class="gloss">night</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>LJLH/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# ## Statistics
#
# To distinguish transitive and intransitive verbs, lexeme and frame are crosstabulated to get the frequencies of each constellation. Afterwards, two subsets are created from the dataframe based on the following rules:
#
# 1. Intransitive: No instances of lexical or suffix object
# 2. Transitives: Instances of either lexical or suffix object

# %%
lex_frames = pd.crosstab(index=df.lex, columns=df.frame)
lex_frames.head()
# Out:
# frame  (S)  (S)-O  (S)-O_sfx
# lex
# <BD[    27    101         44
# <BH[     2      0          0
# <BR[   162     61          0
# <BV[     1      1          0
# <CN[     2      0          0

# %%
intransitive_verbs = lex_frames[(lex_frames['(S)-O'] == 0) & (lex_frames['(S)-O_sfx'] == 0)]

# %%
intransitive_verbs.sort_values(by='(S)', ascending=False)[:20]
# Out:
# frame  (S)  (S)-O  (S)-O_sfx
# lex
# BW>[   978      0          0
# HLK[   787      0          0
# JY>[   397      0          0
# <LH[   352      0          0
# MWT[   327      0          0
# CWB[   295      0          0
# JCB[   282      0          0
# QWM[   260      0          0
# MLK[   178      0          0
# JRD[   176      0          0
# <MD[   139      0          0
# NPL[   132      0          0
# XNH[   113      0          0
# XJH[   105      0          0
# NWS[    96      0          0
# SWR[    87      0          0
# VM>[    69      0          0
# QRB[    63      0          0
# XRH[    58      0          0
# LJN[    36      0          0

# %%
transitive_verbs = lex_frames[(lex_frames['(S)-O'] > 0) | (lex_frames['(S)-O_sfx'] > 0)]

# %%
transitive_verbs.sort_values(by=['(S)',('(S)-O')], ascending=False)[:10]
# Out:
# frame   (S)  (S)-O  (S)-O_sfx
# lex
# >MR[   3168      9          0
# BW>[    978      1          0
# HLK[    787      5          0
# <FH[    629    713         25
# JY>[    397      4          0
# <LH[    352      2          0
# CM<[    318    110         10
# R>H[    254    248         33
# NTN[    219    634        121
# JD<[    216     61         14

# %% [markdown]
# We verify that all lexemes are indeed included in one of the two subsets:

# %%
len(lex_frames)-(len(intransitive_verbs)+len(transitive_verbs))
# Out:
# 0

# %% [markdown]
# ### Surprising cases
#
# It is surprising that a number of motion verbs in fact occurs in transitive frames. These include BW> "arrive", HLK "walk", JY> "go out", and <LH "ascend". These verbs deserve closer attention:

# %%
query = '''
corpus
 clause
  phrase function=Pred|PreS
   word lex={} sp=verb vs=qal language=Hebrew
  phrase function=Objc
'''

# %% [markdown]
# #### 1. BW> "arrive"

# %%
BWO = A.search(query.format('BW>['), sets=sets)
A.show(BWO)
# Out:
#   2.70s 1 result
# <p><b>result</b> <i>1</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis">Genesis</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 42:12">Genesis 42:12</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">sentence</a>   <span class="number">38|3773</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AMRv" title="show this lexeme in SHEBANQ">יֹּ֖אמֶר </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">verb</a></span> <span class="gloss">say</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>MR[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AL" title="show this lexeme in SHEBANQ">אֲלֵהֶ֑ם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">prep</a></span> <span class="gloss">to</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>L</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">sentence</a>   <span class="number">39|3774</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">clause</a>   <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">phrase</a>   <span class="function">Nega</span> <span class="typ">NegP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LA" title="show this lexeme in SHEBANQ">לֹ֕א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">nega</a></span> <span class="gloss">not</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>L></span> <span class="sp xft"><span class="f">sp=</span>nega</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">sentence</a>   <span class="number">40|3775</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">clause</a>   <span class="typ">xQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 42:12" sec="Genesis 42:12">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KJ" title="show this lexeme in SHEBANQ">כִּֽי־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=42&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp

# %% [markdown]
# The clause has not been parsed correctly. Most likely, the object phrase is the object of the infinitive phrase "to see" and not the object of "arrive". We can therefore still treat BW> as an intransitive. Accordingly, the clause is excluded from the analysis:

# %%
exclude_clauses = set()

# %%
exclude_clauses.update([r[1] for r in BWO])

# %% [markdown]
# #### 2. HLK "walk"

# %%
HLK = A.search(query.format('HLK['), sets=sets)
A.show(HLK)
# Out:
#   2.72s 6 results
# <p><b>result</b> <i>1</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers">Numbers</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers 33:8">Numbers 33:8</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">sentence</a>   <span class="number">15|2528</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NSOv" title="show this lexeme in SHEBANQ">יִּסְעוּ֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">verb</a></span> <span class="gloss">pull out</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>NS&lt;[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="show this lexeme in SHEBANQ">מִ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">prep</a></span> <span class="gloss">from</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MN</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1PNHn" title="show this lexeme in SHEBANQ">פְּנֵ֣י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">subs</a></span> <span class="gloss">face</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>PNH/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HXJRWTn" title="show this lexeme in SHEBANQ">הַֽחִירֹ֔ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">nmpr</a></span> <span class="gloss">Pi Hahiroth</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>HXJRWT/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">sentence</a>   <span class="number">16|2529</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 33:8" sec="Numbers 33:8">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=33&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp
# <p><b>result</b> <i>2</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Deuteronomy">Deuteronomy</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Deuteronomy 1:19">Deuteronomy 1:19</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">sentence</a>   <span class="number">40</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NSOv" title="show this lexeme in SHEBANQ">נִּסַּ֣ע </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">verb</a></span> <span class="gloss">pull out</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>NS&lt;[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="show this lexeme in SHEBANQ">מֵ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">prep</a></span> <span class="gloss">from</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MN</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XRBiiin" title="show this lexeme in SHEBANQ">חֹרֵ֗ב </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">nmpr</a></span> <span class="gloss">Horeb</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>XRB===/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">sentence</a>   <span class="number">41</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HLKv" title="show this lexeme in SHEBANQ">נֵּ֡לֶךְ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?bo
# <p><b>result</b> <i>3</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Deuteronomy">Deuteronomy</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Deuteronomy 1:19">Deuteronomy 1:19</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">sentence</a>   <span class="number">40</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NSOv" title="show this lexeme in SHEBANQ">נִּסַּ֣ע </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">verb</a></span> <span class="gloss">pull out</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>NS&lt;[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="show this lexeme in SHEBANQ">מֵ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">prep</a></span> <span class="gloss">from</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MN</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XRBiiin" title="show this lexeme in SHEBANQ">חֹרֵ֗ב </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">nmpr</a></span> <span class="gloss">Horeb</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>XRB===/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">sentence</a>   <span class="number">41</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  l hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">clause</a>   <span class="typ">Way0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=19&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 1:19" sec="Deuteronomy 1:19">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HLKv" title="show this lexeme in SHEBANQ">נֵּ֡לֶךְ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?bo
# <p><b>result</b> <i>4</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Deuteronomy">Deuteronomy</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Deuteronomy 2:7">Deuteronomy 2:7</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">sentence</a>   <span class="number">18|139</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">clause</a>   <span class="typ">XQtl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KJ" title="show this lexeme in SHEBANQ">כִּי֩ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">conj</a></span> <span class="gloss">that</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>KJ</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  l " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">phrase</a>   <span class="function">Subj</span> <span class="typ">PrNP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JHWHn" title="show this lexeme in SHEBANQ">יְהוָ֨ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">nmpr</a></span> <span class="gloss">YHWH</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JHWH/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">phrase</a>   <span class="function">Subj</span> <span class="typ">PrNP|NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ALHJMn" title="show this lexeme in SHEBANQ">אֱלֹהֶ֜יךָ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">subs</a></span> <span class="gloss">god(s)</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>LHJM/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">phrase</a>   <span class="function">PreO</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BRKv" title="show this lexeme in SHEBANQ">בֵּֽרַכְךָ֗ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">verb</a></span> <span class="gloss">bless</span> <span class="vs">piel</span> <span class="vt">perf</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>BRK[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">prep</a></span> <span class="gloss">in</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>B</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KLn" title="show this lexeme in SHEBANQ">כֹל֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Deuteronomy 2:7" sec="Deuteronomy 2:7">subs</a></span> <span class="gloss">whole</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>KL/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MOFHn" title="show this lexeme in SHEBANQ">מַעֲשֵׂ֣ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Deuteronomium&amp;chapter=2&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&am
# <p><b>result</b> <i>5</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Judges">Judges</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Judges 5:6">Judges 5:6</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">sentence</a>   <span class="number">7|365</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">clause</a>   <span class="typ">xQtX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  l " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">phrase</a>   <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">prep</a></span> <span class="gloss">in</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>B</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">ימֵ֞י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">subs</a></span> <span class="gloss">day</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JWM/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CMGRn" title="show this lexeme in SHEBANQ">שַׁמְגַּ֤ר </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">nmpr</a></span> <span class="gloss">Shamgar</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>CMGR/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">phrase</a>   <span class="function">Time</span> <span class="typ">PP|NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BNn" title="show this lexeme in SHEBANQ">בֶּן־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">subs</a></span> <span class="gloss">son</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>BN/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ONTn" title="show this lexeme in SHEBANQ">עֲנָת֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">nmpr</a></span> <span class="gloss">Anath</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>&lt;NT/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">phrase</a>   <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">prep</a></span> <span class="gloss">in</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>B</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">ימֵ֣י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">subs</a></span> <span class="gloss">day</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JWM/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JOLin" title="show this lexeme in SHEBANQ">יָעֵ֔ל </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:6" sec="Judges 5:6">nmpr</a></span> <span class="gloss">Jael</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>J&lt;L=/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.a
# <p><b>result</b> <i>6</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="1_Kings">1_Kings</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="1_Kings 19:4">1_Kings 19:4</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">sentence</a>   <span class="number">11|1941</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">clause</a>   <span class="typ">WXQt</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">phrase</a>   <span class="function">Subj</span> <span class="typ">PPrP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HWA" title="show this lexeme in SHEBANQ">הֽוּא־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">prps</a></span> <span class="gloss">he</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>HW></span> <span class="sp xft"><span class="f">sp=</span>prps</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HLKv" title="show this lexeme in SHEBANQ">הָלַ֤ךְ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">verb</a></span> <span class="gloss">walk</span> <span class="vs">qal</span> <span class="vt">perf</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>HLK[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">prep</a></span> <span class="gloss">in</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>B</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">art</a></span> <span class="gloss">the</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>H</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MDBRn" title="show this lexeme in SHEBANQ">מִּדְבָּר֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">subs</a></span> <span class="gloss">desert</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MDBR/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">phrase</a>   <span class="function">Objc</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1DRKn" title="show this lexeme in SHEBANQ">דֶּ֣רֶךְ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=19&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 19:4" sec="1_Kings 19:4">subs</a></span> <span class="gloss">way</span> <span class="language xft"><span class="f">language=</span>Hebrew</span

# %% [markdown]
# In all these cases, the object phrase is not specifying an object affected by the predicate but is modifying the verb differently, either denoting time, or place or the nature of the path to walk. All the cases will be removed:

# %%
exclude_clauses.update([r[1] for r in HLK])

# %% [markdown]
# #### 3. JY> "go out"

# %%
JYA = A.search(query.format('JY>['), sets=sets)
A.show(JYA)
# Out:
#   2.32s 4 results
# <p><b>result</b> <i>1</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis">Genesis</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 44:4">Genesis 44:4</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">sentence</a>   <span class="number">8|4014</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">clause</a>   <span class="typ">XQtl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">phrase</a>   <span class="function">Subj</span> <span class="typ">PPrP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HM" title="show this lexeme in SHEBANQ">הֵ֠ם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">prps</a></span> <span class="gloss">they</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>HM</span> <span class="sp xft"><span class="f">sp=</span>prps</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JYAv" title="show this lexeme in SHEBANQ">יָֽצְא֣וּ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">verb</a></span> <span class="gloss">go out</span> <span class="vs">qal</span> <span class="vt">perf</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JY>[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">prep</a></span> <span class="gloss">&lt;object marker></span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>T</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">art</a></span> <span class="gloss">the</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>H</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OJRn" title="show this lexeme in SHEBANQ">עִיר֮ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">subs</a></span> <span class="gloss">town</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>&lt;JR/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">sentence</a>   <span class="number">9|4015</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">clause</a>   <span class="typ">xQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">phrase</a>   <span class="function">Nega</span> <span class="typ">NegP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LA" title="show this lexeme in SHEBANQ">לֹ֣א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 44:4" sec="Genesis 44:4">nega</a></span> <span class="gloss">not</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>L></span> <span class="sp xft"><span class="f">sp=</span>nega</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=44&amp;verse=4&amp;version
# <p><b>result</b> <i>2</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus">Exodus</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus 9:29">Exodus 9:29</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">sentence</a>   <span class="number">83|810</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">clause</a>   <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AMRv" title="show this lexeme in SHEBANQ">יֹּ֤אמֶר </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">verb</a></span> <span class="gloss">say</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>MR[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AL" title="show this lexeme in SHEBANQ">אֵלָיו֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">prep</a></span> <span class="gloss">to</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>L</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">phrase</a>   <span class="function">Subj</span> <span class="typ">PrNP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MCHin" title="show this lexeme in SHEBANQ">מֹשֶׁ֔ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">nmpr</a></span> <span class="gloss">Moses</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MCH=/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">sentence</a>   <span class="number">84|811</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">clause</a>   <span class="rela">Adju</span> <span class="typ">InfC</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">phrase</a>   <span class="function">PreS</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1K" title="show this lexeme in SHEBANQ">כְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">prep</a></span> <span class="gloss">as</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>K</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JYAv" title="show this lexeme in SHEBANQ">צֵאתִי֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:29" sec="Exodus 9:29">verb</a></span> <span class="gloss">go out</span> <span cla
# <p><b>result</b> <i>3</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus">Exodus</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus 9:33">Exodus 9:33</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">sentence</a>   <span class="number">94|821</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">clause</a>   <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JYAv" title="show this lexeme in SHEBANQ">יֵּצֵ֨א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">verb</a></span> <span class="gloss">go out</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JY>[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">phrase</a>   <span class="function">Subj</span> <span class="typ">PrNP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MCHin" title="show this lexeme in SHEBANQ">מֹשֶׁ֜ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">nmpr</a></span> <span class="gloss">Moses</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MCH=/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">phrase</a>   <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="show this lexeme in SHEBANQ">מֵ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">prep</a></span> <span class="gloss">from</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MN</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OM" title="show this lexeme in SHEBANQ">עִ֤ם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">prep</a></span> <span class="gloss">with</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>&lt;M</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1PROHn" title="show this lexeme in SHEBANQ">פַּרְעֹה֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">subs</a></span> <span class="gloss">pharaoh</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>PR&lt;H/</span> <span class="sp xft"><span class="f">sp=</span>subs</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AT" title="show this lexeme in SHEBANQ">אֶת־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=9&amp;verse=33&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 9:33" sec="Exodus 9:33">prep</a></span> <span class="gloss">&lt;object marker></span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span
# <p><b>result</b> <i>4</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers">Numbers</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers 35:26">Numbers 35:26</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">sentence</a>   <span class="number">59|2747</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  hl" >
#
#     <div class="clause hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">clause</a>   <span class="typ">WxYX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AM" title="show this lexeme in SHEBANQ">אִם־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">conj</a></span> <span class="gloss">if</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>M</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">phrase</a>   <span class="function">Modi</span> <span class="typ">AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JYAv" title="show this lexeme in SHEBANQ">יָצֹ֥א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">advb</a></span> <span class="gloss">go out</span> <span class="vs">qal</span> <span class="vt">infa</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JY>[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JYAv" title="show this lexeme in SHEBANQ">יֵצֵ֖א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">verb</a></span> <span class="gloss">go out</span> <span class="vs">qal</span> <span class="vt">impf</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>JY>[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">phrase</a>   <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">art</a></span> <span class="gloss">the</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>H</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1RYXv" title="show this lexeme in SHEBANQ">רֹצֵ֑חַ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">subs</a></span> <span class="gloss">kill</span> <span class="vs">qal</span> <span class="vt">ptca</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>RYX[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=35&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 35:26" sec="Numbers 35:26">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <di

# %% [markdown]
# In all 4 cases, the object should probably be interpreted as "source", that is, "from the town", so the accusative is not a real object in these examples. All cases are excluded:

# %%
exclude_clauses.update([r[1] for r in JYA])

# %% [markdown]
# #### 4. <LH "go up"

# %%
ALH = A.search(query.format('<LH['), sets=sets)
A.show(ALH)
# Out:
#   2.37s 2 results
# <p><b>result</b> <i>1</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers">Numbers</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers 13:17">Numbers 13:17</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">sentence</a>   <span class="number">24|894</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">clause</a>   <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CLXv" title="show this lexeme in SHEBANQ">יִּשְׁלַ֤ח </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">verb</a></span> <span class="gloss">send</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>CLX[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AT" title="show this lexeme in SHEBANQ">אֹתָם֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">prep</a></span> <span class="gloss">&lt;object marker></span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>T</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Subj</span> <span class="typ">PrNP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MCHin" title="show this lexeme in SHEBANQ">מֹשֶׁ֔ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">nmpr</a></span> <span class="gloss">Moses</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MCH=/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">clause</a>   <span class="rela">Adju</span> <span class="typ">InfC</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1L" title="show this lexeme in SHEBANQ">לָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">prep</a></span> <span class="gloss">to</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>L</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1TWRv" title="show this lexeme in SHEBANQ">ת֖וּר </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">verb</a></span> <span class="gloss">spy</span> <span class="vs">qal</span> <span class="vt">infc</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>TWR[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div c
# <p><b>result</b> <i>2</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers">Numbers</a>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers 13:17">Numbers 13:17</a></div>
#
#     </div>
#
# <div class="satom  " >
#
#     <div class="sentence " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">sentence</a>   <span class="number">24|894</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">clause</a>   <span class="typ">WayX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">conj</a></span> <span class="gloss">and</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CLXv" title="show this lexeme in SHEBANQ">יִּשְׁלַ֤ח </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">verb</a></span> <span class="gloss">send</span> <span class="vs">qal</span> <span class="vt">wayq</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>CLX[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Objc</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AT" title="show this lexeme in SHEBANQ">אֹתָם֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">prep</a></span> <span class="gloss">&lt;object marker></span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>>T</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Subj</span> <span class="typ">PrNP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MCHin" title="show this lexeme in SHEBANQ">מֹשֶׁ֔ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">nmpr</a></span> <span class="gloss">Moses</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>MCH=/</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">clause</a>   <span class="rela">Adju</span> <span class="typ">InfC</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1L" title="show this lexeme in SHEBANQ">לָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">prep</a></span> <span class="gloss">to</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>L</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1TWRv" title="show this lexeme in SHEBANQ">ת֖וּר </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=13&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 13:17" sec="Numbers 13:17">verb</a></span> <span class="gloss">spy</span> <span class="vs">qal</span> <span class="vt">infc</span> <span class="language xft"><span class="f">language=</span>Hebrew</span> <span class="lex xft"><span class="f">lex=</span>TWR[</span> <span class="sp xft"><span class="f">sp=</span>verb</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div c

# %% [markdown]
# In both cases, the object phrases should rather be understood as locatives. Both cases are excluded:

# %%
exclude_clauses.update([r[1] for r in ALH])

# %% [markdown]
# The cases revisited here demonstrate that the object phrase in the corpus is not clearly defined. The accussative particle (את) can be used with direct objects but can also be used with other modifiers of the verb. Joüon-Muraoka distinguish between direct accussative on the one hand (i.e. affected/effected objects) and indirect accussative on the other hand (i.e. indirectly modifying the verb, sometimes place and time). So far, there is no feature in the database accouting for this difference, so this ambiguity will certainly affect the results of the transitivity frame extraction.

# %% [markdown]
# ### Updated transitivity analysis

# %% [markdown]
# For now, we redo the analysis while excluding the clauses addressed here:

# %%
df1 = df[~df.index.isin(exclude_clauses)]

# %%
df_transitivity = pd.crosstab(index=df1.lex, columns=df1.frame)
df_transitivity.head()
# Out:
# frame  (S)  (S)-O  (S)-O_sfx
# lex
# <BD[    27    101         44
# <BH[     2      0          0
# <BR[   162     61          0
# <BV[     1      1          0
# <CN[     2      0          0

# %%
conditions = [
    (df_transitivity['(S)-O'] == 0) & (df_transitivity['(S)-O_sfx'] == 0)]

choices = ['intransitive']
df_transitivity['transitivity'] = np.select(conditions, choices, default='transitive')

# %%
df_transitivity.head()
# Out:
# frame  (S)  (S)-O  (S)-O_sfx  transitivity
# lex
# <BD[    27    101         44    transitive
# <BH[     2      0          0  intransitive
# <BR[   162     61          0    transitive
# <BV[     1      1          0    transitive
# <CN[     2      0          0  intransitive

# %% [markdown]
# ## Logical structures

# %% [markdown]
# The logical structures are created on the basis of Aktionsart and transitivity. This section combines both features for computation of simple logical structures according to the definitions provided by RRG.

# %% [markdown]
# Fundamentally, there are two types of logical structures, one for stative verbs, and one for active verbs. Each of these can be expanded with certain modifiers, but they will not be accounted for here.
#
# Types:
# * Stative: pred' (x) or (x, y)
# * Active: do' (x, [pred' (x) or (x, y)])

# %% [markdown]
# If the verb is intransitive, only the x-slot will be filled. For transitive verbs, both the x- and y-slot will be filled.

# %% [markdown]
# First, we also need to import the data of activity/stativity:

# %%
data = pd.read_csv('active_stative_verbs_pca_evaluated.csv')
data = data[['lex', 'Aktionsart']]

# %% [markdown]
# The following function generates a general logical struture for each verb without inserting specific arguments:

# %%
def getAktionsart(pred):
    for r in data.iterrows():
        lex = str(r[1].lex)
        if '_' in lex:
            lex = lex[lex.index('_')+1:]
            if pred == lex:
                Aktionsart = r[1].Aktionsart
                return Aktionsart

# %%
def genericLogicalStructure(pred):
    
    Aktionsart = getAktionsart(pred)

    if not Aktionsart:
        return "No Aktionsart annotated"
    
    else:
        #Transitivity
        transitivity = df_transitivity[df_transitivity.index == pred].transitivity.item()
        
        if Aktionsart == 'stative' and transitivity == 'intransitive':
            return f"{pred}' (x)"
        elif Aktionsart == 'stative' and transitivity == 'transitive':
            return f"{pred}' (x, y)"
        elif Aktionsart == 'active' and transitivity == 'intransitive':
            return f"do' (x, [{pred}' (x)])"
        elif Aktionsart == 'active' and transitivity == 'transitive':
            return f"do' (x, [{pred}' (x, y)])"
        else:
            return "No logical structure"

genericLogicalStructure('R>H[')
# Out:
# "R>H[' (x, y)"

# %% [markdown]
# The next function takes specific clauses for parsing into specific logical structures including the arguments:

# %%
def logicalStructure(clause):
    
    A.pretty(clause)
    
    #Parsing clause to get predicate, subject, object and complement
    subj = ''
    objc = ''
    pred = ''
    for ph in L.d(clause, 'phrase'):
        if F.function.v(ph) in ['Subj']:
            subj += T.text(L.d(ph, 'word')).rstrip()
            
        if F.function.v(ph) in ['Objc']:
            objc += T.text(L.d(ph, 'word')).rstrip()

        if F.function.v(ph) in ['Pred','PreO','PreS','PreC']:
            for w in L.d(ph, 'word'):
                if F.sp.v(w) == 'verb':
                    pred = F.lex.v(w)
                    stem = F.vs.v(w)        
    if not pred:
        return "No predicate"
    
    if stem not in ['nif','hof','pual']:
        x = subj
        y = objc
    else:
        x = objc
        y = subj
        
    if not x:
        x = 'nan'
    
    Aktionsart = getAktionsart(pred)

    if not Aktionsart:
        return "No Aktionsart annotated"
        
    else:
        if Aktionsart == 'stative' and not y:
            return f"{pred}' ({x})"
        elif Aktionsart == 'stative' and y:
            return f"{pred}' ({x}, {y})"
        elif Aktionsart == 'active' and not y:
            return f"do' ({x}, [{pred}' ({x})])"
        elif Aktionsart == 'active' and y:
            return f"do' ({x}, [{pred}' ({x}, {y})])"
        else:
            return "No logical structure"
    
logicalStructure(427582)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 1:9">Genesis 1:9</a>
# <div class="atoms  " >
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">clause</a>   <span class="typ">WYqX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">phrase</a>   <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">conj</a></span> <span class="gloss">and</span> <span class="lex xft"><span class="f">lex=</span>W</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">phrase</a>   <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1RAHv" title="show this lexeme in SHEBANQ">תֵרָאֶ֖ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">verb</a></span> <span class="gloss">see</span> <span class="vs">nif</span> <span class="vt">impf</span> <span class="lex xft"><span class="f">lex=</span>R>H[</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">phrase</a>   <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">art</a></span> <span class="gloss">the</span> <span class="lex xft"><span class="f">lex=</span>H</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JBCHn" title="show this lexeme in SHEBANQ">יַּבָּשָׁ֑ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 1:9" sec="Genesis 1:9">subs</a></span> <span class="gloss">dry land</span> <span class="lex xft"><span class="f">lex=</span>JBCH/</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# "R>H[' (nan, הַיַּבָּשָׁ֑ה)"
